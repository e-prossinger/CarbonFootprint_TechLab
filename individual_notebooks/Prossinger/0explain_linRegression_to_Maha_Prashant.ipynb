# %% [markdown]
# # explaining linear Regression to Maha and Prashant
#
# where is our Data from: https://www.kaggle.com/datasets/dumanmesut/individual-carbon-footprint-calculation/data
#
# guide how to do lineare Regression from Falko: https://medium.com/machine-learning-with-python/multiple-linear-regression-implementation-in-python-2de9b303fc0c

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('Carbon_Emission.csv',sep=";")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#linear Regresssion
import pandas as pd

from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

df=pd.read_csv('Carbon_Emission.csv',sep=";")

X= df[["Monthly Grocery Bill", "Vehicle Monthly Distance Km", "Waste Bag Weekly Count", "How Long TV PC Daily Hour", "How Many New Clothes Monthly", "How Long Internet Daily Hour"]]
y = df["CarbonEmission"]



    ##Splitting the dataset into train and test set
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.75)

    ##Implementing the linear model
model = LinearRegression()
model.fit(X_train, y_train)

    ##Evaluating the Model
print("Bestimmtheitsmass:",model.score(X_test, y_test))
# Out:
# Bestimmtheitsmass: 0.4645477813882892

# %%
dataset = pd.read_csv('Carbon_Emission.csv',sep=";")
dataset.head()
# Out:
#     Body Type     Sex         Diet How Often Shower Heating Energy Source  \
# 0  overweight  female  pescatarian            daily                  coal
# 1       obese  female   vegetarian  less frequently           natural gas
# 2  overweight    male     omnivore  more frequently                  wood
# 3  overweight    male     omnivore      twice a day                  wood
# 4       obese  female   vegetarian            daily                  coal
#
#       Transport Vehicle Type Social Activity  Monthly Grocery Bill  \
# 0        public          NaN           often                   230
# 1  walk/bicycle          NaN           often                   114
# 2       private       petrol           never                   138
# 3  walk/bicycle          NaN       sometimes                   157
# 4       private       diesel           often                   266
#
#   Frequency of Traveling by Air  Vehicle Monthly Distance Km Waste Bag Size  \
# ...

# %%
dataset.dtypes
# Out:
# Body Type                        object
# Sex                              object
# Diet                             object
# How Often Shower                 object
# Heating Energy Source            object
# Transport                        object
# Vehicle Type                     object
# Social Activity                  object
# Monthly Grocery Bill              int64
# Frequency of Traveling by Air    object
# Vehicle Monthly Distance Km       int64
# Waste Bag Size                   object
# Waste Bag Weekly Count            int64
# How Long TV PC Daily Hour         int64
# How Many New Clothes Monthly      int64
# How Long Internet Daily Hour      int64
# Energy efficiency                object
# Recycling                        object
# Cooking_With                     object
# CarbonEmission                    int64
# dtype: object

# %%
#Setting the value for X and Y
x = dataset[["Monthly Grocery Bill", "Vehicle Monthly Distance Km", "Waste Bag Weekly Count", "How Long TV PC Daily Hour", "How Many New Clothes Monthly", "How Long Internet Daily Hour"]]

y = dataset["CarbonEmission"]

x
# Out:
#       Monthly Grocery Bill  Vehicle Monthly Distance Km  \
# 0                      230                          210
# 1                      114                            9
# 2                      138                         2472
# 3                      157                           74
# 4                      266                         8457
# ...                    ...                          ...
# 9995                   230                          268
# 9996                   234                         5316
# 9997                   298                           96
# 9998                   179                         8688
# 9999                   115                         9952
#
#       Waste Bag Weekly Count  How Long TV PC Daily Hour  \
# 0                          4                          7
# 1                          3                          9
# 2                          1                         14
# 3                          3                         20
# ...

# %%
#Splitting the dataset into train and test set

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 100)

# %%
from sklearn.model_selection import train_test_split

# Ensure both lists have the same length
persons = ["person1", "person2", "person3", "person4", "person5", "person6", "person7", "person8", "person9"]
prices = ["price1", "price2", "price3", "price4", "price5", "price6", "price7", "price8", "price9"]

# Split the data
train_data, test_data, train_labels, test_labels = train_test_split(persons, prices, test_size=0.3)

print("Train Data:", train_data)
print("Test Data:", test_data)
print("Train Labels:", train_labels)
print("Test Labels:", test_labels)
# Out:
# Train Data: ['person8', 'person5', 'person2', 'person6', 'person1', 'person7']
# Test Data: ['person4', 'person3', 'person9']
# Train Labels: ['price8', 'price5', 'price2', 'price6', 'price1', 'price7']
# Test Labels: ['price4', 'price3', 'price9']

# %%
#Splitting the dataset into train and test set

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 100)
x_train
# Out:
#       Monthly Grocery Bill  Vehicle Monthly Distance Km  \
# 1191                   275                          657
# 4458                    81                            9
# 1131                   128                           70
# 9562                   193                         2716
# 6579                   141                           95
# ...                    ...                          ...
# 350                    276                         2698
# 79                      75                           72
# 8039                   226                         7638
# 6936                   160                         2820
# 5640                    54                           13
#
#       Waste Bag Weekly Count  How Long TV PC Daily Hour  \
# 1191                       2                          9
# 4458                       5                         21
# 1131                       4                          7
# 9562                       5                          4
# ...

# %%
#Fitting the Multiple Linear Regression model

from sklearn.linear_model import LinearRegression
mlr = LinearRegression()  
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Intercept and Coefficient
print("Intercept: ", mlr.intercept_)
print("Coefficients:")
list(zip(x, mlr.coef_))
# Out:
# Intercept:  886.7235044267925
# Coefficients:
# [('Monthly Grocery Bill', 0.9907704093811158),
#  ('Vehicle Monthly Distance Km', 0.2198437986494526),
#  ('Waste Bag Weekly Count', 80.06692173780124),
#  ('How Long TV PC Daily Hour', 2.1179023409370084),
#  ('How Many New Clothes Monthly', 13.548238943954672),
#  ('How Long Internet Daily Hour', 6.49390928167398)]

# %%
#regression equation

all_feature_names=["Monthly Grocery Bill", "Vehicle Monthly Distance Km", "Waste Bag Weekly Count", "How Long TV PC Daily Hour", "How Many New Clothes Monthly", "How Long Internet Daily Hour"]
regression_equation ="Regression Equation: CarbonEmission = "
for variable, slope in list(zip(all_feature_names, mlr.coef_)):
   regression_equation += "(" + str(round(slope,5)) + "*" + variable + ") + "
regression_equation += str(round(mlr.intercept_,3)) + " + Error\n"
print(regression_equation)
# Out:
# Regression Equation: CarbonEmission = (0.99077*Monthly Grocery Bill) + (0.21984*Vehicle Monthly Distance Km) + (80.06692*Waste Bag Weekly Count) + (2.1179*How Long TV PC Daily Hour) + (13.54824*How Many New Clothes Monthly) + (6.49391*How Long Internet Daily Hour) + 886.724 + Error

# %%
x_test.head(1)
# Out:
#       Monthly Grocery Bill  Vehicle Monthly Distance Km  \
# 8018                   158                            4
#
#       Waste Bag Weekly Count  How Long TV PC Daily Hour  \
# 8018                       4                         21
#
#       How Many New Clothes Monthly  How Long Internet Daily Hour
# 8018                            43                            22

# %%
#prediction/calculation of a person

#for 1 person: id 0
mlr.predict([
    [158,4,4,21,43,22]
])
#"Monthly Grocery Bill", "Vehicle Monthly Distance Km", "Waste Bag Weekly Count", "How Long TV PC Daily Hour", "How Many New Clothes Monthly", "How Long Internet Daily Hour"
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/elisabeth_python-umgebung_nr1/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2134.3285192])

# %%
#prediction/calculation of a person

#for 1 person: a person similar to id 0
mlr.predict([
    [308,40,4,21,43,22]
])
#"Monthly Grocery Bill", "Vehicle Monthly Distance Km", "Waste Bag Weekly Count", "How Long TV PC Daily Hour", "How Many New Clothes Monthly", "How Long Internet Daily Hour"
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/elisabeth_python-umgebung_nr1/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2290.85845736])

# %%
dataset.loc[8018]
# Out:
# Body Type                                           overweight
# Sex                                                     female
# Diet                                                  omnivore
# How Often Shower                               less frequently
# Heating Energy Source                              natural gas
# Transport                                         walk/bicycle
# Vehicle Type                                               NaN
# Social Activity                                          often
# Monthly Grocery Bill                                       158
# Frequency of Traveling by Air                  very frequently
# Vehicle Monthly Distance Km                                  4
# Waste Bag Size                                           large
# Waste Bag Weekly Count                                       4
# How Long TV PC Daily Hour                                   21
# How Many New Clothes Monthly                                43
# ...

# %%
#Prediction of test set
y_pred_mlr= mlr.predict(x_test)
#Predicted values
print(y_pred_mlr)
# Out:
# [2134.3285192  3043.55493551 2339.86991554 ... 2752.28702927 2422.35230614
#  4189.7710845 ]

# %%
#Prediction of train set
y_pred_mlr= mlr.predict(x_train)
#Predicted values
print(y_pred_mlr)
# Out:
# [2069.08378923 2007.08547125 1616.39694258 ... 3519.4331402  2296.55511325
#  1742.89754628]

# %%
x_train
# Out:
#       Monthly Grocery Bill  Vehicle Monthly Distance Km  \
# 1191                   275                          657
# 4458                    81                            9
# 1131                   128                           70
# 9562                   193                         2716
# 6579                   141                           95
# ...                    ...                          ...
# 350                    276                         2698
# 79                      75                           72
# 8039                   226                         7638
# 6936                   160                         2820
# 5640                    54                           13
#
#       Waste Bag Weekly Count  How Long TV PC Daily Hour  \
# 1191                       2                          9
# 4458                       5                         21
# 1131                       4                          7
# 9562                       5                          4
# ...

# %%
x_test
# Out:
#       Monthly Grocery Bill  Vehicle Monthly Distance Km  \
# 8018                   158                            4
# 9225                   297                         4733
# 3854                   266                            2
# 2029                   220                         1706
# 3539                   191                           85
# ...                    ...                          ...
# 4208                   190                         1834
# 5335                   281                         6484
# 2554                    60                         7285
# 13                     111                         2893
# 4468                   276                         9592
#
#       Waste Bag Weekly Count  How Long TV PC Daily Hour  \
# 8018                       4                         21
# 9225                       2                         16
# 3854                       6                         12
# 2029                       1                         21
# ...

# %%
dataset.head(1)
# Out:
#     Body Type     Sex         Diet How Often Shower Heating Energy Source  \
# 0  overweight  female  pescatarian            daily                  coal
#
#   Transport Vehicle Type Social Activity  Monthly Grocery Bill  \
# 0    public          NaN           often                   230
#
#   Frequency of Traveling by Air  Vehicle Monthly Distance Km Waste Bag Size  \
# 0                    frequently                          210          large
#
#    Waste Bag Weekly Count  How Long TV PC Daily Hour  \
# 0                       4                          7
#
#    How Many New Clothes Monthly  How Long Internet Daily Hour  \
# 0                            26                             1
#
#   Energy efficiency  Recycling       Cooking_With  CarbonEmission
# 0                No  ['Metal']  ['Stove', 'Oven']            2238

# %%
mlr_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred_mlr})
mlr_diff.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 mlr_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred_mlr})
#       2 mlr_diff.head()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/elisabeth_python-umgebung_nr1/lib/python3.11/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
#Model Evaluation
#1=100% perfect. 
# 0=0% bad. 
#over 90% is a good model

print("R squared/Bestimmtheitsmass/Coefficient of determination:",mlr.score(x_test,y_test))
# Out:
# R squared/Bestimmtheitsmass/Coefficient of determination: 0.4302595690950076
